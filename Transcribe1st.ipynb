# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavcodeshard/Data-Scientist/blob/main/Transcribe1st.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello future Multi-Billionaire")
# Out:
# Hello future Multi-Billionaire

# %%
#to instal the whisper library for transcribe
# !pip install openai-whisper
#to install ffmpg for audio support
# !apt-get install -y ffmpeg

#to import the whisper library
import whisper
#to import the file handeling library from google colab
from google.colab import files

from transformers import pipeline

#to select model from whisper
model = whisper.load_model('base')
#to upload the audio file from the system
upload_audio = files.upload()

#to select the current audio from files
current_audio = list(upload_audio.keys())[0]
#to pass the current audio to modelfor transcribe
output =  model.transcribe(current_audio)
#to print the text result from audio
print(output['text'])

# The variable 'transcribe' was not defined, using output['text'] instead
sentiment = pipeline('sentiment-analysis')
sentiment_text = sentiment(output['text'])
print(sentiment_text)
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
#      <input type="file" id="files-3415b323-a003-4b9b-a3c1-f6ef94b23dba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3415b323-a003-4b9b-a3c1-f6ef94b23dba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# ...
